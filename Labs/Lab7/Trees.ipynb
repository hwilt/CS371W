# %%
import numpy as np
import matplotlib.pyplot as plt

class TreeNode(object):
    def __init__(self, key):
        self.key = key
        self.left = None
        self.right = None
        self.inorder_pos = 0
        self.height = 0
    
    def add(self, key):
        ret = self
        if key < self.key:
            if self.left:
                self.left = self.left.add(key)
            else:
                self.left = TreeNode(key)
        elif key > self.key:
            if self.right:
                self.right = self.right.add(key)
            else:
                self.right = TreeNode(key)
        return ret
    
    def inorder(self, num, key_list):
        """
        Parameters
        ----------
        num: list
            List of a single element which keeps 
            track of the number I'm at
        """
        if self.left:
            self.left.inorder(num, key_list)
        self.inorder_pos = num[0]
        key_list.append(self.key)
        num[0] += 1
        if self.right:
            self.right.inorder(num, key_list)
    
    def draw(self, y):
        x = self.inorder_pos
        plt.scatter([x], [y], 50, 'k')
        plt.text(x+0.2, y, "{}".format(self.key))
        plt.text(x+0.7, y, "({})".format(self.height), color='r')
        y_next = y-1
        if self.left:
            x_next = self.left.inorder_pos
            plt.plot([x, x_next], [y, y_next])
            self.left.draw(y_next)
        if self.right:
            x_next = self.right.inorder_pos
            plt.plot([x, x_next], [y, y_next])
            self.right.draw(y_next)
        
        
class BinaryTree(object):
    def __init__(self):
        self.root = None
    
    def inorder(self):
        key_list = []
        if self.root:
            self.root.inorder([0], key_list)
        return key_list
    
    def draw(self):
        self.inorder()
        if self.root:
            self.root.draw(0)
    
    def add(self, key):
        if self.root:
            self.root = self.root.add(key)
        else:
            self.root = TreeNode(key)

    def getheight(self, root):
        if self.root:
            return 0
        else:
            return self.root.height
    
    def getbalance(self, root):
        if self.root:
            return 0
        else:
            return self.getheight(root.left) - self.getheight(root.right)

def make_tree():
    T = BinaryTree()
    for val in [10, 7, 16, 3, 9, 11, 20, 14, 17, 13, 12, 6, 5, 17, 15, 8, 4]:
        T.add(val)
    return T

T = make_tree()
plt.figure()
T.draw()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_25035/42396355.py in <module>
#     123     return T
#     124
# --> 125 T = make_tree()
#     126 plt.figure()
#     127 T.draw()
#
# /tmp/ipykernel_25035/42396355.py in make_tree()
#     120     T = BinaryTree()
#     121     for val in [10, 7, 16, 3, 9, 11, 20, 14, 17, 13, 12, 6, 5, 17, 15, 8, 4]:
# --> 122         T.add(val)
#     123     return T
#     124
#
# /tmp/ipykernel_25035/42396355.py in add(self, key)
#     113     def add(self, key):
#     114         if self.root:
# --> 115             self.root = self.root.add(key)
#     116         else:
#     117             self.root = TreeNode(key)
#
# /tmp/ipykernel_25035/42396355.py in add(self, key)
#      28                 if self.left.right.height > self.left.left.height:
#      29                     self.left = self.rotateleft(left)
# ---> 30                 ret = rotateright(node)
#      31
#      32             elif self.left.height == self.right.height - 2:
#
# NameError: name 'rotateright' is not defined
